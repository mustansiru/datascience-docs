# %%
# import package and its set of stopwords
from wordcloud import WordCloud, STOPWORDS

print ('Wordcloud is installed and imported!')
# Out:
# Wordcloud is installed and imported!

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
import matplotlib.pyplot as plt
import PyPDF2 
import textract
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mustan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
filename = 'D:\personal\zainab-thesis-phd\Zainab-Bohra-Thesis-v5-corrected.pdf' 
pdfFileObj = open(filename,'rb')
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
num_pages = pdfReader.numPages
count = 0
text = ""
num_pages
# Out:
# 173

# %%
while count < num_pages:
    pageObj = pdfReader.getPage(count)
    count +=1
    text += pageObj.extractText()
text
# Out:
# 'A Study of Impact of School Teaching\n-\nLearning Facilities \non Psychological Competencies of Adolescence\n \n \nA Thesis\n \n \nS\nubmitted for the Award of Ph. D. degree of\n \n \nMOHANLAL SUKHADIA UNIVERSITY\n \n \nin the\n \n \nFaculty of Social Sciences\n \n \nBy\n \n \nZainab \nBohra\n \n \n \n \nUnder the s\nupervision of\n \nDr A. R. Lohia (Assoc. Professor)\n \nGovt. Meera Girls College\n \n \nDEPARTMENT OF PSYCHOLOGY\n \nFACULTY OF SOCIAL SCIENCES\n \nMOHANLAL SUKHADIA UNIVERSITY,\n \nUDAIPUR (RAJ)\n \n \n \nDECLARATION\n \n \nI\n, Zainab Bohra,\n \nhereby\n \ndeclare that the work incorporated in the pres\nent\n \nthesis \nentitled \n\n-\nLearning Facilities on \n\n \nis my \nown\n \nwork and is original. \nThis work (in part or in full) has not \nbeen submi\ntted\n \nto any University for the award \nof a Degre\ne or a Diploma.\n \n \n \nSignature of the Candidate\n \n \n \n \n \nCERTIFICATE\n \n \nI\n \nfeel great pleasure in certifying that the thesis entitled\n \n\n
# ...

# %%
if text != "":
   text = text
else:
   text = textract.process(fileurl, method='tesseract', language='eng')

# %%
text
tokens = word_tokenize(text)
punctuations = ['(',')',';',':','[',']',',']
stop_words = stopwords.words('english')
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
keywords = [word for word in tokens if not word in stop_words and not word in punctuations]

# %%
keywords
# Out:
# ['A',
#  'Study',
#  'Impact',
#  'School',
#  'Teaching',
#  '-',
#  'Learning',
#  'Facilities',
#  'Psychological',
#  'Competencies',
#  'Adolescence',
#  'A',
#  'Thesis',
#  'S',
#  'ubmitted',
#  'Award',
#  'Ph',
#  '.',
#  'D.',
#  'degree',
#  'MOHANLAL',
#  'SUKHADIA',
#  'UNIVERSITY',
#  'Faculty',
#  'Social',
#  'Sciences',
#  'By',
#  'Zainab',
#  'Bohra',
#  'Under',
#  'upervision',
#  'Dr',
#  'A.',
#  'R.',
#  'Lohia',
#  'Assoc',
#  '.',
#  'Professor',
#  'Govt',
#  '.',
#  'Meera',
#  'Girls',
#  'College',
#  'DEPARTMENT',
#  'OF',
#  'PSYCHOLOGY',
#  'FACULTY',
#  'OF',
#  'SOCIAL',
#  'SCIENCES',
#  'MOHANLAL',
#  'SUKHADIA',
#  'UNIVERSITY',
#  'UDAIPUR',
#  'RAJ',
#  'DECLARATION',
#  'I',
#  'Zainab',
#  'Bohra',
#  'hereby',
#  'declare',
#  'work',
#  'incorporated',
#  'pres',
#  'ent',
#  'thesis',
#  'entitled',
#  '-',
#  'Learning',
#  'Facilities',
#  'work',
#  'original',
#  '.',
#  'This',
#  'work',
#  'part',
#  'full',
#  'submi',
#  'tted',
# ...

# %%
stopwords = set(STOPWORDS)
stopwords.add('.')
stopwords.add('..')
stopwords.add('...')
text = " ".join(str(item) for item in keywords)
wc = WordCloud(
    background_color='white',
    max_words=2000,
    stopwords=stopwords
)
wc.generate(text)

# %%
fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height

# display the cloud
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#import wget
#url = "https://svgsilh.com/png-1024/1547551.png"
url = "D:\personal\zainab-thesis-phd\grad_mask.png"
file = open(url, "r")
#!wget --quiet https://svgsilh.com/png-1024/1547551.png -O grad_mask.png

img_mask = np.array(Image.open(file.name))

words = ['facilitie', 'Mean', 'SD', 'diagram', 'showing', 'found', 'better', 'Figure', 'Column']
for word in words:
    stopwords.add(word)

font_path = "D:\personal\zainab-thesis-phd\Lato\Lato-Regular.ttf"

wc = WordCloud(background_color='black', max_words=1000, mask=img_mask, stopwords=stopwords, font_path=font_path)

# generate the word cloud
wc.generate(text)

# display the word cloud
fig = plt.figure()
fig.set_figwidth(24) # set width
fig.set_figheight(48) # set height

plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
